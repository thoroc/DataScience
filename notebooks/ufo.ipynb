# %%
import pandas as pd
from pathlib import Path
from openpyxl import load_workbook
from colorama import Fore, Back, Style

FILENAME = 'UFO Data.xlsx'
CWD = Path.cwd()

file_path = Path(CWD.parent, 'data', FILENAME)
df = pd.read_excel(file_path)
df
# Out:
#         Date / Time                 City State     Shape     Duration  \
# 0    12/23/20 07:30       Canadian Lakes    MI     Light    5 seconds
# 1    12/23/20 03:18               Grants    CA     Light    2 Seconds
# 2    12/23/20 03:00          East Quogue    NY     Other      30 mins
# 3    12/22/20 22:45  Indian River Shores    FL  Changing    4 minutes
# 4    12/22/20 22:05        lake elsinore    CA     Light   30 seconds
# ..              ...                  ...   ...       ...          ...
# 256   12/1/20 14:45              Weidman    MI     Light  4-5 minutes
# 257   12/1/20 12:00            Millstone    NJ    Circle       5 mins
# 258   12/1/20 09:00    Barnegat Township    NJ   Unknown       30 min
# 259   12/1/20 06:00            Hyde Park    VT   Diamond       30 sec
# 260   12/1/20 05:09            Jonesboro    AR       NaN          NaN
#
#                                                Summary    Posted
# 0                               light in sky ,no sound  12/23/20
# 1    Bright Orb seen below plane level at Mach 1+ S...  12/23/20
# 2    flickering colored lights in the night sky, in...  12/23/20
# 3          Orange orb over Indian River Shores Florida  12/23/20
# 4    saw a glowing object.shape not discerned. trav...  12/23/20
# ..                                                 ...       ...
# 256  Extremely bright mirror like light that left v...  12/23/20
# 257  It flew across highway dropped to the ground a...  12/23/20
# 258  Witnessed object being chased by fighter jets ...  12/23/20
# 259  I saw a very bright light in the sky and then ...  12/23/20
# 260                                     MADAR Node 143  12/23/20
#
# [261 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['Date / Time', 'City', 'State', 'Shape', 'Duration', 'Summary',
#        'Posted'],
#       dtype='object')

# %%
def get_sheetnames_xlsx(file_path):
    wb = load_workbook(file_path, read_only=True, keep_links=False)
    return wb.sheetnames


sheet_names = get_sheetnames_xlsx(file_path)
sheet_names
# Out:
# ['12th',
#  '11th',
#  '10th',
#  '9th',
#  '8th',
#  '7th',
#  '6th',
#  '5th',
#  '4th',
#  '3rd',
#  '2nd',
#  '1st']

# %%
def load_frame(file_path, sheet_name):
    raw_data = pd.read_excel(file_path, sheet_name=sheet_name, header=None)
    # looking for the header row
    for index, row in raw_data.iterrows():
        
        if row.notnull().all():
            data = raw_data.iloc[(index + 1):].reset_index(drop=True)
            data.columns = list(raw_data.iloc[index])
            break
    # transforming columns to numeric where possible
    for c in data.columns:
        data[c] = pd.to_numeric(data[c], errors='ignore')

    return data

data = load_frame(file_path, sheet_names[10])
data.head()
# Out:
#      Date / Time           City State     Shape    Duration  \
# 0  2/29/20 23:38        Livonia    MI     Other  30 seconds
# 1  2/29/20 21:30      New Haven    MI  Fireball  30 seconds
# 2  2/29/20 21:00          Solon    ME    Circle      1 hour
# 3  2/29/20 20:54   Clear Spring    MD     Light  30 minutes
# 4  2/29/20 20:40  Spring Branch    TX    Circle  15 minutes
#
#                                              Summary               Posted
# 0  Object was moving very fast and low in the nig...  2020-09-04 00:00:00
# 1                                    Fiery porthole.  2020-09-04 00:00:00
# 2  Red Pulsating light left, white on right, much...  2020-09-04 00:00:00
# 3  You can see in the video. I was trying my best...  2020-09-04 00:00:00
# 4  It was just above tree line and was moving fir...  2020-09-04 00:00:00

# %%
def load_wb(file_path):
    names = get_sheetnames_xlsx(file_path)
    frames = []
    for n in names:
        print(f'> {Fore.CYAN}loading sheet{Style.RESET_ALL} "{n}"')
        df = load_frame(file_path, n)
        print(f'found {len(df)} records')
        frames.append(df)
    return pd.concat(frames)

df = load_wb(file_path)
df.head()
# Out:
# > loading sheet "12th"
# found 261 records
# > loading sheet "11th"
# found 468 records
# > loading sheet "10th"
# found 508 records
# > loading sheet "9th"
# found 440 records
# > loading sheet "8th"
# found 700 records
# > loading sheet "7th"
# found 639 records
# > loading sheet "6th"
# found 367 records
# > loading sheet "5th"
# found 563 records
# > loading sheet "4th"
# found 1040 records
# > loading sheet "3rd"
# found 816 records
# > loading sheet "2nd"
# found 607 records
# > loading sheet "1st"
# found 611 records
#       Date / Time                 City State     Shape    Duration  \
# 0  12/23/20 07:30       Canadian Lakes    MI     Light   5 seconds
# 1  12/23/20 03:18               Grants    CA     Light   2 Seconds
# 2  12/23/20 03:00          East Quogue    NY     Other     30 mins
# 3  12/22/20 22:45  Indian River Shores    FL  Changing   4 minutes
# 4  12/22/20 22:05        lake elsinore    CA     Light  30 seconds
#
#                                              Summary    Posted
# 0                             light in sky ,no sound  12/23/20
# 1  Bright Orb seen below plane level at Mach 1+ S...  12/23/20
# 2  flickering colored lights in the night sky, in...  12/23/20
# 3        Orange orb over Indian River Shores Florida  12/23/20
# 4  saw a glowing object.shape not discerned. trav...  12/23/20

# %%
frames = [load_frame(file_path, n) for n in sheet_names]
df = pd.concat(frames)
df.head()
# Out:
#       Date / Time                 City State     Shape    Duration  \
# 0  12/23/20 07:30       Canadian Lakes    MI     Light   5 seconds
# 1  12/23/20 03:18               Grants    CA     Light   2 Seconds
# 2  12/23/20 03:00          East Quogue    NY     Other     30 mins
# 3  12/22/20 22:45  Indian River Shores    FL  Changing   4 minutes
# 4  12/22/20 22:05        lake elsinore    CA     Light  30 seconds
#
#                                              Summary    Posted
# 0                             light in sky ,no sound  12/23/20
# 1  Bright Orb seen below plane level at Mach 1+ S...  12/23/20
# 2  flickering colored lights in the night sky, in...  12/23/20
# 3        Orange orb over Indian River Shores Florida  12/23/20
# 4  saw a glowing object.shape not discerned. trav...  12/23/20

# %%
df.sample(20)
# Out:
#         Date / Time                   City State      Shape          Duration  \
# 184   1/18/20 19:05                  Alamo    TX      Light         7 minutes
# 116   12/7/20 17:56             North Java   NaN      Light      6 to 10 min.
# 177         2/22/20                 Hixson    TN     Circle     30-45 minutes
# 434    1/7/20 05:57                Abilene    TX      Cigar        10 minutes
# 33    3/30/20 21:00             Hillandale    MD     Circle        30 minutes
# 16   10/31/20 09:30              Dade City    FL       Oval        6h 30 mins
# 259   8/19/20 00:10      N. Richland Hills    TX       Disk                 1
# 464         7/10/20             Morristown    TN      Light          2 months
# 153   6/17/20 01:38               Fairview    NJ   Triangle        10 minutes
# 526   4/17/20 21:26       Zagreb (Croatia)   NaN     Circle        10 minutes
# 41    8/30/20 00:00           Bloomingdale    NJ    Unknown           unknown
# 899    4/9/20 02:00         Salt Lake City    UT      Light          1 second
# 616   4/16/20 21:00              Brentwood    CA      Light  20 minutes or so
# 227  11/15/20 18:00               Santa Fe    NM     Sphere            3 mins
# 382   8/14/20 04:30                 Tenino    WA  Formation         5 minutes
# 255   1/14/20 21:10  Nuriootpa (Australia)   NaN      Light         5 minutes
# 272   1/14/20 18:15              Riverside    CA   Triangle          1 minute
# 87    5/24/20 21:00             Middlebury    CT      Light           ~1 hour
# 131   6/18/20 21:30            Garden City    SC     Sphere       Few seconds
# 293   4/24/20 10:30                  Flint    MI   Cylinder        30 seconds
#
#                                                Summary               Posted
# 184      My uncle had seen it moving across the sky...  2020-07-02 00:00:00
# 116  Took dog out. Large bright white light directl...             12/23/20
# 177  While arriving home we saw a large bright ligh...              2/25/20
# 434  It was up and down about an inch long that slo...              1/31/20
# 33                             ((Starlink satellites))              6/25/20
# 16                Ufo above Northern Dade City Florida             12/23/20
# 259  Craft had mainly white light with red and gree...              8/20/20
# 464  For the past two months, at night, I've been w...              7/23/20
# 153  A bunch of unexplained beams of lights coming ...              6/25/20
# 526  We saw 30 circle moving on sky, it was lasting...              6/25/20
# 41                      Animal mutilation possibly UFO  2020-04-09 00:00:00
# 899  Both myself and my boyfriend were looking over...  2020-09-04 00:00:00
# 616  High flying lights one after the other heading...              5/15/20
# 227  A white sphere flying from north to south over...             12/23/20
# 382  I looked up into the sky to see a line formati...              8/20/20
# 255  I witnessed about ten or so star lights travel...  2020-07-02 00:00:00
# 272  I was driving south on Brockton Ave between Ma...  2020-07-02 00:00:00
# 87        I and 3 others observed 4 lights in the sky.              6/25/20
# 131  Large Orb that split into three orbs seen off ...              7/23/20
# 293  20 unidentified bright lights in single form g...              6/25/20

# %%
len(df)
# Out:
# 7020

# %%
len(df['Duration'].unique())
# Out:
# 899

# %%
import os
import sys

sys.path.insert(0, os.path.abspath('../lib'))

import dehumanize
# Out:
#  False
# > REGULAR CASE: ['ninety', 'five', 'hrs']
# > ninety five hrs 	=> 34200.0 Seconds
# > Original String: ninety six hrs
# > Has number: False
# > REGULAR CASE: ['ninety', 'six', 'hrs']
# > ninety six hrs 	=> 34560.0 Seconds
# > Original String: ninety seven hrs
# > Has number: False
# > REGULAR CASE: ['ninety', 'seven', 'hrs']
# > ninety seven hrs 	=> 34920.0 Seconds
# > Original String: ninety eight hrs
# > Has number: False
# > REGULAR CASE: ['ninety', 'eight', 'hrs']
# > ninety eight hrs 	=> 35280.0 Seconds
# > Original String: ninety nine hrs
# > Has number: False
# > REGULAR CASE: ['ninety', 'nine', 'hrs']
# > ninety nine hrs 	=> 35640.0 Seconds
# > Original String: 91h
# > Has number: True
# > REGULAR CASE: ['91h']
# > 91h 	=> 32760.0 Seconds
# > Original String: 91 h
# > Has number: True
# > REGULAR CASE: ['91', 'h']
# > 91 h 	=> 32760.0 Seconds
# > Original String: ~91h
# > Has number: True
# > REGULAR CASE: ['~91h']
# > ~91h 	=> 32760.0 Seconds
# > Original String: ~91 h
# > Has number: True
# > REGULAR CASE: ['~91', 'h']
# > ~91 h 	=> 32760.0 Seconds
# > Original String: 91/165h
# > Has number: True
# > REGULAR CASE: ['91/165h']
# > 91/165h 	=> 59400.0 Seconds
# > Original String: 91/165 h
# > Has number: True
# > REGULAR CASE: ['91/165', 'h']
# > 91/165 h 	=> 59400.0 Seconds
# > Original String: 91 / 165h
# > Has number: True
# > REGULAR CASE: ['91', '/', '165h']
# > 91 / 165h 	=> 59400.0 Seconds
# > Original String: 91 / 165 h
# > Has number: True
# > REGULAR CASE: ['91', '/', '165', 'h']
# > 91 / 165 h 	=> 59400.0 Seconds
# > Original String: 91-165h
# > Has number: True
# > REGULAR CASE: ['91-165h']
# > 91-165h 	=> 59400.0 Seconds
# > Original String: 91-165 h
# > Has number: True
# > REGULAR CASE: ['91-165', 'h']
# > 91-165 h 	=> 59400.0 Seconds
# > Original String: 91 - 165h
# > Has number: True
# > REGULAR CASE: ['91', '-', '165h']
# > 91 - 165h 	=> 59400.0 Seconds
# > Original String: 91 - 165 h
# > Has number: True
# > REGULAR CASE: ['91', '-', '165', 'h']
# > 91 - 165 h 	=> 59400.0 Seconds
# > Original String: 91 to 165 h
# > Has number: True
# > REGULAR CASE: ['91', 'to', '165', 'h']
# > 91 to 165 h 	=> 59400.0 Seconds
# > Original String: about a h
# > Has number: False
# > REGULAR CASE: ['about', 'a', 'h']
# > about a h 	=> 360.0 Seconds
# > Original String: approx. 91 h
# > Has number: True
# > REGULAR CASE: ['approx.', '91', 'h']
# > approx. 91 h 	=> 32760.0 Seconds
# > Original String: approx.91 h
# > Has number: True
# > REGULAR CASE: ['approx.91', 'h']
# > approx.91 h 	=> 32760.0 Seconds
# > Original String: Approx. 91 h
# > Has number: True
# > REGULAR CASE: ['Approx.', '91', 'h']
# > Approx. 91 h 	=> 32760.0 Seconds
# > Original String: Approx.91 h
# > Has number: True
# > REGULAR CASE: ['Approx.91', 'h']
# > Approx.91 h 	=> 32760.0 Seconds
# > Original String: Approximately 91 h
# > Has number: True
# > REGULAR CASE: ['Approximately', '91', 'h']
# > Approximately 91 h 	=> 32760.0 Seconds
# > Original String: Less than 91 h
# > Has number: True
# > REGULAR CASE: ['Less', 'than', '91', 'h']
# > Less than 91 h 	=> 32760.0 Seconds
# > Original String: >91 h
# > Has number: True
# > REGULAR CASE: ['>91', 'h']
# > >91 h 	=> 32760.0 Seconds
# > Original String: 91+ h
# > Has number: True
# > REGULAR CASE: ['91+', 'h']
# > 91+ h 	=> 32760.0 Seconds
# > Original String: zero h
# > Has number: False
# > REGULAR CASE: ['zero', 'h']
# > zero h 	=> 0.0 Seconds
# > Original String: one h
# > Has number: False
# > REGULAR CASE: ['one', 'h']
# > one h 	=> 360.0 Seconds
# > Original String: two h
# > Has number: False
# > REGULAR CASE: ['two', 'h']
# > two h 	=> 720.0 Seconds
# > Original String: three h
# > Has number: False
# > REGULAR CASE: ['three', 'h']
# > three h 	=> 1080.0 Seconds
# > Original String: four h
# > Has number: False
# > REGULAR CASE: ['four', 'h']
# > four h 	=> 1440.0 Seconds
# > Original String: five h
# > Has number: False
# > REGULAR CASE: ['five', 'h']
# > five h 	=> 1800.0 Seconds
# > Original String: six h
# > Has number: False
# > REGULAR CASE: ['six', 'h']
# > six h 	=> 2160.0 Seconds
# > Original String: seven h
# > Has number: False
# > REGULAR CASE: ['seven', 'h']
# > seven h 	=> 2520.0 Seconds
# > Original String: eight h
# > Has number: False
# > REGULAR CASE: ['eight', 'h']
# > eight h 	=> 2880.0 Seconds
# > Original String: nine h
# > Has number: False
# > REGULAR CASE: ['nine', 'h']
# > nine h 	=> 3240.0 Seconds
# > Original String: ten h
# > Has number: False
# > REGULAR CASE: ['ten', 'h']
# > ten h 	=> 3600.0 Seconds
# > Original String: eleven h
# > Has number: False
# > REGULAR CASE: ['eleven', 'h']
# > eleven h 	=> 3960.0 Seconds
# > Original String: twelve h
# > Has number: False
# > REGULAR CASE: ['twelve', 'h']
# > twelve h 	=> 4320.0 Seconds
# > Original String: thirteen h
# > Has number: False
# > REGULAR CASE: ['thirteen', 'h']
# > thirteen h 	=> 4680.0 Seconds
# > Original String: fourteen h
# > Has number: False
# > REGULAR CASE: ['fourteen', 'h']
# > fourteen h 	=> 5040.0 Seconds
# > Original String: fifteen h
# > Has number: False
# > REGULAR CASE: ['fifteen', 'h']
# > fifteen h 	=> 5400.0 Seconds
# > Original String: sixteen h
# > Has number: False
# > REGULAR CASE: ['sixteen', 'h']
# > sixteen h 	=> 5760.0 Seconds
# > Original String: seventeen h
# > Has number: False
# > REGULAR CASE: ['seventeen', 'h']
# > seventeen h 	=> 6120.0 Seconds
# > Original String: eighteen h
# > Has number: False
# > REGULAR CASE: ['eighteen', 'h']
# > eighteen h 	=> 6480.0 Seconds
# > Original String: nineteen h
# > Has number: False
# > REGULAR CASE: ['nineteen', 'h']
# > nineteen h 	=> 6840.0 Seconds
# > Original String: twenty h
# > Has number: False
# > REGULAR CASE: ['twenty', 'h']
# > twenty h 	=> 7200.0 Seconds
# > Original String: twenty one h
# > Has number: False
# > REGULAR CASE: ['twenty', 'one', 'h']
# > twenty one h 	=> 7560.0 Seconds
# > Original String: twenty two h
# > Has number: False
# > REGULAR CASE: ['twenty', 'two', 'h']
# > twenty two h 	=> 7920.0 Seconds
# > Original String: twenty three h
# > Has number: False
# > REGULAR CASE: ['twenty', 'three', 'h']
# > twenty three h 	=> 8280.0 Seconds
# > Original String: twenty four h
# > Has number: False
# > REGULAR CASE: ['twenty', 'four', 'h']
# > twenty four h 	=> 8640.0 Seconds
# > Original String: twenty five h
# > Has number: False
# > REGULAR CASE: ['twenty', 'five', 'h']
# > twenty five h 	=> 9000.0 Seconds
# > Original String: twenty six h
# > Has number: False
# > REGULAR CASE: ['twenty', 'six', 'h']
# > twenty six h 	=> 9360.0 Seconds
# > Original String: twenty seven h
# > Has number: False
# > REGULAR CASE: ['twenty', 'seven', 'h']
# > twenty seven h 	=> 9720.0 Seconds
# > Original String: twenty eight h
# > Has number: False
# > REGULAR CASE: ['twenty', 'eight', 'h']
# > twenty eight h 	=> 10080.0 Seconds
# > Original String: twenty nine h
# > Has number: False
# > REGULAR CASE: ['twenty', 'nine', 'h']
# > twenty nine h 	=> 10440.0 Seconds
# > Original String: thirty h
# > Has number: False
# > REGULAR CASE: ['thirty', 'h']
# > thirty h 	=> 10800.0 Seconds
# > Original String: thirty one h
# > Has number: False
# > REGULAR CASE: ['thirty', 'one', 'h']
# > thirty one h 	=> 11160.0 Seconds
# > Original String: thirty two h
# > Has number: False
# > REGULAR CASE: ['thirty', 'two', 'h']
# > thirty two h 	=> 11520.0 Seconds
# > Original String: thirty three h
# > Has number: False
# > REGULAR CASE: ['thirty', 'three', 'h']
# > thirty three h 	=> 11880.0 Seconds
# > Original String: thirty four h
# > Has number: False
# > REGULAR CASE: ['thirty', 'four', 'h']
# > thirty four h 	=> 12240.0 Seconds
# > Original String: thirty five h
# > Has number: False
# > REGULAR CASE: ['thirty', 'five', 'h']
# > thirty five h 	=> 12600.0 Seconds
# > Original String: thirty six h
# > Has number: False
# > REGULAR CASE: ['thirty', 'six', 'h']
# > thirty six h 	=> 12960.0 Seconds
# > Original String: thirty seven h
# > Has number: False
# > REGULAR CASE: ['thirty', 'seven', 'h']
# > thirty seven h 	=> 13320.0 Seconds
# > Original String: thirty eight h
# > Has number: False
# > REGULAR CASE: ['thirty', 'eight', 'h']
# > thirty eight h 	=> 13680.0 Seconds
# > Original String: thirty nine h
# > Has number: False
# > REGULAR CASE: ['thirty', 'nine', 'h']
# > thirty nine h 	=> 14040.0 Seconds
# > Original String: forty h
# > Has number: False
# > REGULAR CASE: ['forty', 'h']
# > forty h 	=> 14400.0 Seconds
# > Original String: forty one h
# > Has number: False
# > REGULAR CASE: ['forty', 'one', 'h']
# > forty one h 	=> 14760.0 Seconds
# > Original String: forty two h
# > Has number: False
# > REGULAR CASE: ['forty', 'two', 'h']
# > forty two h 	=> 15120.0 Seconds
# > Original String: forty three h
# > Has number: False
# > REGULAR CASE: ['forty', 'three', 'h']
# > forty three h 	=> 15480.0 Seconds
# > Original String: forty four h
# > Has number: False
# > REGULAR CASE: ['forty', 'four', 'h']
# > forty four h 	=> 15840.0 Seconds
# > Original String: forty five h
# > Has number: False
# > REGULAR CASE: ['forty', 'five', 'h']
# > forty five h 	=> 16200.0 Seconds
# > Original String: forty six h
# > Has number: False
# > REGULAR CASE: ['forty', 'six', 'h']
# > forty six h 	=> 16560.0 Seconds
# > Original String: forty seven h
# > Has number: False
# > REGULAR CASE: ['forty', 'seven', 'h']
# > forty seven h 	=> 16920.0 Seconds
# > Original String: forty eight h
# > Has number: False
# > REGULAR CASE: ['forty', 'eight', 'h']
# > forty eight h 	=> 17280.0 Seconds
# > Original String: forty nine h
# > Has number: False
# > REGULAR CASE: ['forty', 'nine', 'h']
# > forty nine h 	=> 17640.0 Seconds
# > Original String: fifty h
# > Has number: False
# > REGULAR CASE: ['fifty', 'h']
# > fifty h 	=> 18000.0 Seconds
# > Original String: fifty one h
# > Has number: False
# > REGULAR CASE: ['fifty', 'one', 'h']
# > fifty one h 	=> 18360.0 Seconds
# > Original String: fifty two h
# > Has number: False
# > REGULAR CASE: ['fifty', 'two', 'h']
# > fifty two h 	=> 18720.0 Seconds
# > Original String: fifty three h
# > Has number: False
# > REGULAR CASE: ['fifty', 'three', 'h']
# > fifty three h 	=> 19080.0 Seconds
# > Original String: fifty four h
# > Has number: False
# > REGULAR CASE: ['fifty', 'four', 'h']
# > fifty four h 	=> 19440.0 Seconds
# > Original String: fifty five h
# > Has number: False
# > REGULAR CASE: ['fifty', 'five', 'h']
# > fifty five h 	=> 19800.0 Seconds
# > Original String: fifty six h
# > Has number: False
# > REGULAR CASE: ['fifty', 'six', 'h']
# > fifty six h 	=> 20160.0 Seconds
# > Original String: fifty seven h
# > Has number: False
# > REGULAR CASE: ['fifty', 'seven', 'h']
# > fifty seven h 	=> 20520.0 Seconds
# > Original String: fifty eight h
# > Has number: False
# > REGULAR CASE: ['fifty', 'eight', 'h']
# > fifty eight h 	=> 20880.0 Seconds
# > Original String: fifty nine h
# > Has number: False
# > REGULAR CASE: ['fifty', 'nine', 'h']
# > fifty nine h 	=> 21240.0 Seconds
# > Original String: sixty h
# > Has number: False
# > REGULAR CASE: ['sixty', 'h']
# > sixty h 	=> 21600.0 Seconds
# > Original String: sixty one h
# > Has number: False
# > REGULAR CASE: ['sixty', 'one', 'h']
# > sixty one h 	=> 21960.0 Seconds
# > Original String: sixty two h
# > Has number: False
# > REGULAR CASE: ['sixty', 'two', 'h']
# > sixty two h 	=> 22320.0 Seconds
# > Original String: sixty three h
# > Has number: False
# > REGULAR CASE: ['sixty', 'three', 'h']
# > sixty three h 	=> 22680.0 Seconds
# > Original String: sixty four h
# > Has number: False
# > REGULAR CASE: ['sixty', 'four', 'h']
# > sixty four h 	=> 23040.0 Seconds
# > Original String: sixty five h
# > Has number: False
# > REGULAR CASE: ['sixty', 'five', 'h']
# > sixty five h 	=> 23400.0 Seconds
# > Original String: sixty six h
# > Has number: False
# > REGULAR CASE: ['sixty', 'six', 'h']
# > sixty six h 	=> 23760.0 Seconds
# > Original String: sixty seven h
# > Has number: False
# > REGULAR CASE: ['sixty', 'seven', 'h']
# > sixty seven h 	=> 24120.0 Seconds
# > Original String: sixty eight h
# > Has number: False
# > REGULAR CASE: ['sixty', 'eight', 'h']
# > sixty eight h 	=> 24480.0 Seconds
# > Original String: sixty nine h
# > Has number: False
# > REGULAR CASE: ['sixty', 'nine', 'h']
# > sixty nine h 	=> 24840.0 Seconds
# > Original String: seventy h
# > Has number: False
# > REGULAR CASE: ['seventy', 'h']
# > seventy h 	=> 25200.0 Seconds
# > Original String: seventy one h
# > Has number: False
# > REGULAR CASE: ['seventy', 'one', 'h']
# > seventy one h 	=> 25560.0 Seconds
# > Original String: seventy two h
# > Has number: False
# > REGULAR CASE: ['seventy', 'two', 'h']
# > seventy two h 	=> 25920.0 Seconds
# > Original String: seventy three h
# > Has number: False
# > REGULAR CASE: ['seventy', 'three', 'h']
# > seventy three h 	=> 26280.0 Seconds
# > Original String: seventy four h
# > Has number: False
# > REGULAR CASE: ['seventy', 'four', 'h']
# > seventy four h 	=> 26640.0 Seconds
# > Original String: seventy five h
# > Has number: False
# > REGULAR CASE: ['seventy', 'five', 'h']
# > seventy five h 	=> 27000.0 Seconds
# > Original String: seventy six h
# > Has number: False
# > REGULAR CASE: ['seventy', 'six', 'h']
# > seventy six h 	=> 27360.0 Seconds
# > Original String: seventy seven h
# > Has number: False
# > REGULAR CASE: ['seventy', 'seven', 'h']
# > seventy seven h 	=> 27720.0 Seconds
# > Original String: seventy eight h
# > Has number: False
# > REGULAR CASE: ['seventy', 'eight', 'h']
# > seventy eight h 	=> 28080.0 Seconds
# > Original String: seventy nine h
# > Has number: False
# > REGULAR CASE: ['seventy', 'nine', 'h']
# > seventy nine h 	=> 28440.0 Seconds
# > Original String: eighty h
# > Has number: False
# > REGULAR CASE: ['eighty', 'h']
# > eighty h 	=> 28800.0 Seconds
# > Original String: eighty one h
# > Has number: False
# > REGULAR CASE: ['eighty', 'one', 'h']
# > eighty one h 	=> 29160.0 Seconds
# > Original String: eighty two h
# > Has number: False
# > REGULAR CASE: ['eighty', 'two', 'h']
# > eighty two h 	=> 29520.0 Seconds
# > Original String: eighty three h
# > Has number: False
# > REGULAR CASE: ['eighty', 'three', 'h']
# > eighty three h 	=> 29880.0 Seconds
# > Original String: eighty four h
# > Has number: False
# > REGULAR CASE: ['eighty', 'four', 'h']
# > eighty four h 	=> 30240.0 Seconds
# > Original String: eighty five h
# > Has number: False
# > REGULAR CASE: ['eighty', 'five', 'h']
# > eighty five h 	=> 30600.0 Seconds
# > Original String: eighty six h
# > Has number: False
# > REGULAR CASE: ['eighty', 'six', 'h']
# > eighty six h 	=> 30960.0 Seconds
# > Original String: eighty seven h
# > Has number: False
# > REGULAR CASE: ['eighty', 'seven', 'h']
# > eighty seven h 	=> 31320.0 Seconds
# > Original String: eighty eight h
# > Has number: False
# > REGULAR CASE: ['eighty', 'eight', 'h']
# > eighty eight h 	=> 31680.0 Seconds
# > Original String: eighty nine h
# > Has number: False
# > REGULAR CASE: ['eighty', 'nine', 'h']
# > eighty nine h 	=> 32040.0 Seconds
# > Original String: ninety h
# > Has number: False
# > REGULAR CASE: ['ninety', 'h']
# > ninety h 	=> 32400.0 Seconds
# > Original String: ninety one h
# > Has number: False
# > REGULAR CASE: ['ninety', 'one', 'h']
# > ninety one h 	=> 32760.0 Seconds
# > Original String: ninety two h
# > Has number: False
# > REGULAR CASE: ['ninety', 'two', 'h']
# > ninety two h 	=> 33120.0 Seconds
# > Original String: ninety three h
# > Has number: False
# > REGULAR CASE: ['ninety', 'three', 'h']
# > ninety three h 	=> 33480.0 Seconds
# > Original String: ninety four h
# > Has number: False
# > REGULAR CASE: ['ninety', 'four', 'h']
# > ninety four h 	=> 33840.0 Seconds
# > Original String: ninety five h
# > Has number: False
# > REGULAR CASE: ['ninety', 'five', 'h']
# > ninety five h 	=> 34200.0 Seconds
# > Original String: ninety six h
# > Has number: False
# > REGULAR CASE: ['ninety', 'six', 'h']
# > ninety six h 	=> 34560.0 Seconds
# > Original String: ninety seven h
# > Has number: False
# > REGULAR CASE: ['ninety', 'seven', 'h']
# > ninety seven h 	=> 34920.0 Seconds
# > Original String: ninety eight h
# > Has number: False
# > REGULAR CASE: ['ninety', 'eight', 'h']
# > ninety eight h 	=> 35280.0 Seconds
# > Original String: ninety nine h
# > Has number: False
# > REGULAR CASE: ['ninety', 'nine', 'h']
# > ninety nine h 	=> 35640.0 Seconds
# Tested 1830 cases against 1830 initial cases.

# %%
class UnknownTimeFrameException(Exception):
    '''
    Exception raised when no timeframe is found.

    Attributes:
        timeframe -- time frame
        message -- explaination of the erro
    '''

    def __init__(self, timeframe, message='Could not recognize time frame: {}'):
        self.timeframe = timeframe
        self.message = message.format(timeframe)
        super().__init__(self.message)


class CouldNotConvertTimeFrameException(Exception):
    '''
    Exception raised when timeframe is not convertible.

    Attributes:
        value -- user defined input
        timeframe -- time frame
        message -- explaination of the erro
    '''

    def __init__(self, value, timeframe, message='"{}" does note translate to a time frame [{} Seconds]'):
        self.value = value
        self.timeframe = timeframe
        self.message = message.format(value, timeframe)
        super().__init__(self.message)


class MatchingTimeNotFoundException(Exception):
    '''
    Exception raised when timeframe is not convertible.

    Attributes:
        duration -- user defined input
        pattern -- time frame
        message -- explaination of the erro
    '''

    def __init__(self, duration, pattern, message='Failing to match anything in string: "{}" using pattern: "{}"'):
        self.duration = duration
        self.pattern = pattern
        self.message = message.format(duration, pattern)
        super().__init__(self.message)


class WrongTypeException(Exception):
    '''
    Exception raised when duration is of the wrong type.

    Attributes:
        duration -- user defined input
        message -- explaination of the erro
    '''

    def __init__(self, duration, message='Cannot convert "{}": wrong type "{}"'):
        self.duration = duration
        self.message = message.format(duration, type(duration))
        super().__init__(self.message)

# %%
sep = '\\s*'
range_separator = ['/', '-', 'to']
range_numbers = '|'.join(
    [f'\\d{{1,3}}{sep}{rs}{sep}\\d{{1,3}}' for rs in range_separator])

regex = f'(:?[~|approx\\.|Approximately|>]*){sep}(\\d{{1,3}}|{range_numbers}|about a)\\+*{sep}(\\w*)'
print(regex)
# Out:
# (:?[~|approx\.|Approximately|>]*)\s*(\d{1,3}|\d{1,3}\s*/\s*\d{1,3}|\d{1,3}\s*-\s*\d{1,3}|\d{1,3}\s*to\s*\d{1,3}|about a)\+*\s*(\w*)

# %%
import re
from random import randint
from text2digits import text2digits

UNITS = ['zero', 'one', 'two', 'three', 'four',
         'five', 'six', 'seven', 'eight', 'nine']
TEENS = ['ten', 'eleven', 'twelve', 'thirteen', 'fourteen', 'fifteen', 'sixteen', 'seventeen', 'eighteen',
         'nineteen']
TENS = ['twenty', 'thirty', 'forty', 'fifty',
        'sixty', 'seventy', 'eighty', 'ninety']


def get_matches(human_readable_duration, regex):
    matches = []
    t2d = text2digits.Text2Digits(convert_ordinals=False)
    # special case
    SPECIAL_CASE = 'second'
    split_str = human_readable_duration.split(' ')
    time_frame = split_str[-1:][0]
    filtered = ' '.join([s for s in split_str if s != SPECIAL_CASE])

    if time_frame == SPECIAL_CASE and filtered in TENS:
        print(f'> {Fore.RED}SPECIAL CASE:{Style.RESET_ALL} {split_str}')
        print(f'> {Fore.RED}SPLITED:{Style.RESET_ALL} {filtered}')
        clean_str = t2d.convert(filtered)
        matches = [('', clean_str, time_frame)]
        print(f'> {Fore.RED}SPECIAL MATCHES:{Style.RESET_ALL} {matches}')
    else:
        print(f'> {Fore.CYAN}REGULAR CASE:{Style.RESET_ALL} {split_str}')
        clean_str = t2d.convert(human_readable_duration)
        matches = re.findall(regex, clean_str)

    return (matches, clean_str)

def extract_time(human_readable_duration, regex):
    duration = -1
    time_frame = False
    matches, clean_str = get_matches(human_readable_duration, regex)
    if len(matches) == 0:
        return (matches, time_frame, MatchingTimeNotFoundException(clean_str, regex))

    if len(matches) == 1:
        group = matches[0]
        duration = 1 if group[1] == 'about a' else int(group[1])
        time_frame = group[2]
    # if we have a range ie: 1-2, 1/2, 1 to 2
    elif len(matches) == 2:
        # averaging between groups
        group_min = matches[1]
        duration_min = int(group_min[1])
        group_max = matches[1]
        duration_max = int(group_max[1])
        duration = (duration_min + duration_max) / 2
        time_frame = group_max[2]

    return (duration, time_frame, None)


def to_seconds(human_readable_duration, regex):
    if not isinstance(human_readable_duration, str):
        return (None, WrongTypeException(human_readable_duration))
    duration, time_frame, err = extract_time(human_readable_duration, regex)
    if time_frame is not False:
        if time_frame.lower() in TF_SECONDS:
            return (duration, None)
        elif time_frame.lower() in TF_MINUTES:
            return (duration * 60, None)
        elif time_frame.lower() in TF_HOURS:
            return (duration * 360, None)
    return (None, UnknownTimeFrameException(time_frame))

# %%
def get_apnumbers():
    nums = []
    nums = [*nums, *UNITS, *TEENS]

    for n in TENS:
        for u in UNITS:
            curr = n if u == UNITS[0] else f'{n} {u}'
            nums.append(curr)
    return nums

TF_SECONDS = ['seconds', 'second', 'sec', 'secs', 's']
TF_MINUTES = ['minute', 'minutes', 'min', 'mins', 'm']
TF_HOURS = ['hour', 'hours', 'hr', 'hrs', 'h']
TIME_FRAMES = [*TF_SECONDS, *TF_MINUTES, *TF_HOURS]

durations = []
min_duration = randint(0, 99)
max_duration = min_duration + randint(1, 99)
for tf in TIME_FRAMES:
    durations.append(f'{min_duration}{tf}')
    durations.append(f'{min_duration} {tf}')
    durations.append(f'~{min_duration}{tf}')
    durations.append(f'~{min_duration} {tf}')
    durations.append(f'{min_duration}/{max_duration}{tf}')
    durations.append(f'{min_duration}/{max_duration} {tf}')
    durations.append(f'{min_duration} / {max_duration}{tf}')
    durations.append(f'{min_duration} / {max_duration} {tf}')
    durations.append(f'{min_duration}-{max_duration}{tf}')
    durations.append(f'{min_duration}-{max_duration} {tf}')
    durations.append(f'{min_duration} - {max_duration}{tf}')
    durations.append(f'{min_duration} - {max_duration} {tf}')
    durations.append(f'{min_duration} to {max_duration} {tf}')
    durations.append(f'about a {tf}')
    durations.append(f'approx. {min_duration} {tf}')
    durations.append(f'approx.{min_duration} {tf}')
    durations.append(f'Approx. {min_duration} {tf}')
    durations.append(f'Approx.{min_duration} {tf}')
    durations.append(f'Approximately {min_duration} {tf}')
    durations.append(f'>{min_duration} {tf}')
    durations.append(f'{min_duration}+ {tf}')

    for a in get_apnumbers():
        durations.append(f'{a} {tf}')

print(f'{Back.GREEN}Testing to_second{Style.RESET_ALL}')
count = 0
for d in durations:
    seconds = float(to_seconds(d, regex))
    if seconds == -1:
        raise CouldNotConvertTimeFrameException(d, seconds)
    else:
        print(f'> {Fore.CYAN}{d}{Style.RESET_ALL} \t=> {seconds} Seconds')
    count += 1

print(f'Tested {count} cases against {len(durations)} initial cases.')
# Out:
# Testing to_second
# > REGULAR CASE: ['9seconds']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-55d072c21717> in <module>
#      46 count = 0
#      47 for d in durations:
# ---> 48     seconds = float(to_seconds(d, regex))
#      49     if seconds == -1:
#      50         raise CouldNotConvertTimeFrameException(d, seconds)
#
# TypeError: float() argument must be a string or a number, not 'tuple'

# %%
df['Duration'].apply(lambda x: to_seconds(x, regex))
# Out:
# > REGULAR CASE: ['5', 'seconds']
# > REGULAR CASE: ['2', 'Seconds']
# > REGULAR CASE: ['30', 'mins']
# > REGULAR CASE: ['4', 'minutes']
# > REGULAR CASE: ['30', 'seconds']
# > REGULAR CASE: ['45', 'seconds']
# > REGULAR CASE: ['20', 'seconds']
# > REGULAR CASE: ['While', 'taken', 'pictures']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['20', 'seconds']
# > REGULAR CASE: ['5', 'seconds']
# > REGULAR CASE: ['4', 'seconds']
# > REGULAR CASE: ['4', 'seconds']
# > REGULAR CASE: ['4', 'seconds']
# > REGULAR CASE: ['1-3', 'seconds']
# > REGULAR CASE: ['1-2', 'mins']
# > REGULAR CASE: ['12', 'minutes']
# > REGULAR CASE: ['15-20', 'min']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['2hrs']
# > REGULAR CASE: ['2-3', 'minutes']
# > REGULAR CASE: ['40', 'mins']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['20-', '25', 'minutes']
# > REGULAR CASE: ['15-30m']
# > REGULAR CASE: ['20', 'seconds']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['15', 'minutes']
# > REGULAR CASE: ['2', 'seconds']
# > REGULAR CASE: ['10', 'seconds']
# > REGULAR CASE: ['2', 'hours']
# > REGULAR CASE: ['10', 'minutes']
# > REGULAR CASE: ['10', 'minutes']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['3', 'hours']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['2', 'min']
# > REGULAR CASE: ['&lt;1min']
# > REGULAR CASE: ['30', 'seconds']
# > REGULAR CASE: ['Driving']
# > REGULAR CASE: ['1', 'min']
# > REGULAR CASE: ['One', 'second']
# > REGULAR CASE: ['23', 'mins']
# > REGULAR CASE: ['23', 'mins']
# > REGULAR CASE: ['4', 'minutes']
# > REGULAR CASE: ['4', 'minutes']
# > REGULAR CASE: ['1', 'second']
# > REGULAR CASE: ['30', 'seconds']
# > REGULAR CASE: ['Seconds']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['5', 'min']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['2', 'to', '3', 'mins']
# > REGULAR CASE: ['4', 'minutes']
# > REGULAR CASE: ['10', 'minutes']
# > REGULAR CASE: ['10', 'seconds']
# > REGULAR CASE: ['2min']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['15', 'min']
# > REGULAR CASE: ['3', 'hours']
# > REGULAR CASE: ['Ongoing', '24/7']
# > REGULAR CASE: ['Continuing']
# > REGULAR CASE: ['Two', 'seconds']
# > REGULAR CASE: ['Two', 'seconds']
# > REGULAR CASE: ['&lt;1', 'minute']
# > REGULAR CASE: ['3', 'to', '4', 'seconds']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['30', 'seconds']
# > REGULAR CASE: ['1', 'second']
# > REGULAR CASE: ['30', 'minutes']
# > REGULAR CASE: ['8', 'seconds']
# > REGULAR CASE: ['3', 'seconds']
# > REGULAR CASE: ['45', 'mins', 'plus']
# > REGULAR CASE: ['10', 'seconds']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['1', 'hour']
# > REGULAR CASE: ['44', 'minutes']
# > REGULAR CASE: ['30', 'minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['Unknown']
# > REGULAR CASE: ['All', 'night']
# > REGULAR CASE: ['Five', 'minutes']
# > REGULAR CASE: ['6-7', 'hours']
# > REGULAR CASE: ['5-10', 'minutes']
# > REGULAR CASE: ['ten', 'minutes']
# > REGULAR CASE: ['3-5m', 'minutes']
# > REGULAR CASE: ['15', 'minutes']
# > REGULAR CASE: ['10', 'seconds']
# > REGULAR CASE: ['5', 'mins']
# > REGULAR CASE: ['8-10', 'minutes']
# > REGULAR CASE: ['8-10', 'minutes']
# > REGULAR CASE: ['30', 'min']
# > REGULAR CASE: ['2', 'hours']
# > REGULAR CASE: ['4-5', 'seconds']
# > REGULAR CASE: ['5', 'minuetes']
# > REGULAR CASE: ['a', 'few', 'hours']
# > REGULAR CASE: ['5', 'min']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['2', 'hours']
# > REGULAR CASE: ['6', 'to', '10', 'min.']
# > REGULAR CASE: ['20', 'seconds']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['Less', 'than', '1', 'minute']
# > REGULAR CASE: ['Less', 'than', '1', 'minute']
# > REGULAR CASE: ['30', 'seconds']
# > REGULAR CASE: ['30', 'seconds']
# > REGULAR CASE: ['10', 'mins']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['45', 'seconds']
# > REGULAR CASE: ['10', 'ninutes']
# > REGULAR CASE: ['6', 'Minutes']
# > REGULAR CASE: ['2', 'seconds']
# > REGULAR CASE: ['10mins']
# > REGULAR CASE: ['10mins']
# > REGULAR CASE: ['About', 'a', 'minute']
# > REGULAR CASE: ['About', 'a', 'minute']
# > REGULAR CASE: ['10', 'min']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['2-3', 'minutes']
# > REGULAR CASE: ['3', 'min']
# > REGULAR CASE: ['3', 'min']
# > REGULAR CASE: ['3', 'min']
# > REGULAR CASE: ['?']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['3-', '5', 'minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['10', 'sec']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['1-2', 'minutes']
# > REGULAR CASE: ['30', 'seconds']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['1', 'hour']
# > REGULAR CASE: ['6', 'seconds']
# > REGULAR CASE: ['5min']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['3-4', 'minutes']
# > REGULAR CASE: ['5min']
# > REGULAR CASE: ['5min']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['approx.', '1', 'minute']
# > REGULAR CASE: ['40s']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['less', 'than', 'a', 'minute']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['3-5', 'minutes']
# > REGULAR CASE: ['7', 'minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['30/45', 'seconds']
# > REGULAR CASE: ['2', 'min']
# > REGULAR CASE: ['4', 'min.']
# > REGULAR CASE: ['5', 'Min']
# > REGULAR CASE: ['5minutes']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['&gt;3', 'min']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['30-45', 'seconds']
# > REGULAR CASE: ['3', 'min']
# > REGULAR CASE: ['30', 'seconds']
# > REGULAR CASE: ['30', 'seconds']
# > REGULAR CASE: ['20', 'seconds']
# > REGULAR CASE: ['20', 'seconds']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['10', 'minutes']
# > REGULAR CASE: ['5', 'min']
# > REGULAR CASE: ['5', 'min']
# > REGULAR CASE: ['~1', 'minute']
# > REGULAR CASE: ['10', 'minutes']
# > REGULAR CASE: ['10', 'minutes']
# > REGULAR CASE: ['10', 'minutes']
# > REGULAR CASE: ['15', '-20', 'seconds']
# > REGULAR CASE: ['10', 'minutes']
# > REGULAR CASE: ['1', 'min']
# > REGULAR CASE: ['30', 'seconds']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['2-3', 'minutes']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['1', 'min+']
# > REGULAR CASE: ['15', 'seconds']
# > REGULAR CASE: ['15', 'seconds']
# > REGULAR CASE: ['4', 'minutes']
# > REGULAR CASE: ['3', 'min']
# > REGULAR CASE: ['3', 'min']
# > REGULAR CASE: ['15', 'minutes']
# > REGULAR CASE: ['4', 'seconds', 'maybe', 'less']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['4', 'mins']
# > REGULAR CASE: ['still', 'live']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['1minute']
# > REGULAR CASE: ['1minute']
# > REGULAR CASE: ['two', 'minutes']
# > REGULAR CASE: ['2', 'seconds']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['Aprox', '2', 'to', '3', 'minutes']
# > REGULAR CASE: ['3:00', 'minutes']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['5:00', 'minutes']
# > REGULAR CASE: ['10', 'seconds']
# > REGULAR CASE: ['1', 'to', '2', 'min']
# > REGULAR CASE: ['3+', 'hours']
# > REGULAR CASE: ['5', 'minutes', 'got', 'scared', 'went']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['1.5', 'Mins']
# > REGULAR CASE: ['1-2', 'minutes']
# > REGULAR CASE: ['all', 'night']
# > REGULAR CASE: ['30', 'minites']
# > REGULAR CASE: ['2', 'seconds']
# > REGULAR CASE: ['8', 'seconds']
# > REGULAR CASE: ['10', 'seconds']
# > REGULAR CASE: ['10', 'seconds']
# > REGULAR CASE: ['4-5', 'minutes']
# > REGULAR CASE: ['5', 'mins']
# > REGULAR CASE: ['30', 'min']
# > REGULAR CASE: ['30', 'sec']
# > REGULAR CASE: ['30', 'minutes']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['15', 'sec']
# > REGULAR CASE: ['15', 'sec']
# > REGULAR CASE: ['5-10', 'seconds']
# > REGULAR CASE: ['1', 'hour']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['5-10', 'seconds']
# > REGULAR CASE: ['5-10', 'seconds']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['5', 'minutes', 'or', 'less']
# > REGULAR CASE: ['20', 'minutes']
# > REGULAR CASE: ['30', 'seconds']
# > REGULAR CASE: ['30', 'minutes']
# > REGULAR CASE: [':03', 'seconds']
# > REGULAR CASE: ['15', 'seconds']
# > REGULAR CASE: ['1.5', 'hours']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['5', 'seconds']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['very', 'short', 'time-less', 'than']
# > REGULAR CASE: ['20', 'min']
# > REGULAR CASE: ['<2', 'seconds']
# > REGULAR CASE: ['Seconds']
# > REGULAR CASE: ['30', 'seconds']
# > REGULAR CASE: ['45', 'seconds']
# > REGULAR CASE: ['45', 'seconds']
# > REGULAR CASE: ['45', 'seconds']
# > REGULAR CASE: ['1', 'hr']
# > REGULAR CASE: ['Over', '1hour']
# > REGULAR CASE: ['2mins']
# > REGULAR CASE: ['80', 'sec']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['1', 'second']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['About', '8', 'mins']
# > REGULAR CASE: ['30mims']
# > REGULAR CASE: ['7-8', 'minutes']
# > REGULAR CASE: ['18mins']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['30', 'seconds']
# > REGULAR CASE: ['15', 'minutes']
# > REGULAR CASE: ['2', 'hours']
# > REGULAR CASE: ['2', 'hours']
# > REGULAR CASE: ['13', 'seconds']
# > REGULAR CASE: ['Unknown']
# > REGULAR CASE: ['10', 'mins']
# > REGULAR CASE: ['10', 'min']
# > REGULAR CASE: ['4sec']
# > REGULAR CASE: ['8', 'minutes']
# > REGULAR CASE: ['20', 'minutes']
# > REGULAR CASE: ['20', 'minutes']
# > REGULAR CASE: ['20', 'minutes']
# > REGULAR CASE: ['3', 'Minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['5', 'min']
# > REGULAR CASE: ['9', 'minutes']
# > REGULAR CASE: ['20', 'seconds']
# > REGULAR CASE: ['20', 'seconds']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['5', 'mins']
# > REGULAR CASE: ['45', 'sec']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['4', 'minutes']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['Approx', '1min', '30', 'sec']
# > REGULAR CASE: ['2', 'min']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['30', 'seconds']
# > REGULAR CASE: ['5-8', 'min']
# > REGULAR CASE: ['45', 'seconds']
# > REGULAR CASE: ['4', 'hrs']
# > REGULAR CASE: ['4', 'hrs']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['10', 'seconds']
# > REGULAR CASE: ['5', 'seconds']
# > REGULAR CASE: ['10', '15min']
# > REGULAR CASE: ['2', 'seconds']
# > REGULAR CASE: ['10', 'minutes']
# > REGULAR CASE: ['4', 'minutes']
# > REGULAR CASE: ['20', 'minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['1', 'hour']
# > REGULAR CASE: ['5', 'seconds']
# > REGULAR CASE: ['4', 'minutes']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['15', 'seconds']
# > REGULAR CASE: ['10', 'seconfs']
# > REGULAR CASE: ['3-5', 'mins']
# > REGULAR CASE: ['15', 'seconds']
# > REGULAR CASE: ['2', 'mins']
# > REGULAR CASE: ['40', 'minutes']
# > REGULAR CASE: ['Seconds']
# > REGULAR CASE: ['2', 'Minutes']
# > REGULAR CASE: ['10', 'MINUTES']
# > REGULAR CASE: ['3', 'min']
# > REGULAR CASE: ['1', 'hour?']
# > REGULAR CASE: ['1', 'hr']
# > REGULAR CASE: ['10-15', 'minutes']
# > REGULAR CASE: ['30', 'seconds']
# > REGULAR CASE: ['2', 'seconds']
# > REGULAR CASE: ['30', 'sec']
# > REGULAR CASE: ['10', 'min']
# > REGULAR CASE: ['30', 'minutes']
# > REGULAR CASE: ['3', 'mins']
# > REGULAR CASE: ['10', 'seconds']
# > REGULAR CASE: ['3.5', 'min']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['5', 'min']
# > REGULAR CASE: ['5', 'min']
# > REGULAR CASE: ['All', 'night', 'every', 'night', 'sin']
# > REGULAR CASE: ['30seconds']
# > REGULAR CASE: ['15', 'minutes']
# > REGULAR CASE: ['Five', 'minutes']
# > REGULAR CASE: ['35', 'seconds']
# > REGULAR CASE: ['5', 'Minutes']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['Less', 'than', '10', 'seconds']
# > REGULAR CASE: ['~30', 'minutes']
# > REGULAR CASE: ['10', 'seconds']
# > REGULAR CASE: ['1', 'hour']
# > REGULAR CASE: [':15']
# > REGULAR CASE: ['4', 'min']
# > REGULAR CASE: ['3', 'minutes']
# > REGULAR CASE: ['2', 'mins']
# > REGULAR CASE: ['1', 'second']
# > REGULAR CASE: ['3', 'seconds']
# > REGULAR CASE: ['3', 'seconds']
# > REGULAR CASE: ['Still', 'there']
# > REGULAR CASE: ['In', 'a', 'feild']
# > REGULAR CASE: ['2', 'seconds']
# > REGULAR CASE: ['50min']
# > REGULAR CASE: ['10', 'minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['3', 'secs']
# > REGULAR CASE: ['4hours']
# > REGULAR CASE: ['3-4', 'minutes']
# > REGULAR CASE: ['3-4', 'minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['Few', 'seconds']
# > REGULAR CASE: ['Approximately', '5', 'minutes']
# > REGULAR CASE: ['30+', 'minutes']
# > REGULAR CASE: ['30+', 'minutes']
# > REGULAR CASE: ['11', 'minutes']
# > REGULAR CASE: ['1', 'min']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['5', 'to', '10', 'minutes']
# > REGULAR CASE: ['A', 'few', 'minutes']
# > REGULAR CASE: ['2', 'min']
# > REGULAR CASE: ['2', 'min']
# > REGULAR CASE: ['5-7', 'minutes']
# > REGULAR CASE: ['15', 'seconds']
# > REGULAR CASE: ['ongoing']
# > REGULAR CASE: ['1', 'hour']
# > REGULAR CASE: ['1hour']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['15', 'min']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['15', 'seconds']
# > REGULAR CASE: ['1', 'min']
# > REGULAR CASE: ['1/2', 'second']
# > REGULAR CASE: ['1', '-', '2', 'minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['45', 'seconds']
# > REGULAR CASE: ['10', 'seconds']
# > REGULAR CASE: ['10', 'seconds']
# > REGULAR CASE: ['3', 'mins']
# > REGULAR CASE: ['1', 'min']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['2', 'minutes']
# > REGULAR CASE: ['5', 'min']
# > REGULAR CASE: ['1.5', 'hours']
# > REGULAR CASE: ['2-3', 'minites']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['3', 'mins']
# > REGULAR CASE: ['3-4', 'mins']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['30', 'Seconds']
# > REGULAR CASE: ['2-3', 'seconds']
# > REGULAR CASE: ['2-3', 'seconds']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['5', 'sec']
# > REGULAR CASE: ['20', 'mins']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['30', 'to', '45', 'minutes']
# > REGULAR CASE: ['15', 'seconds']
# > REGULAR CASE: ['2', 'hours']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['10', 'Minutes']
# > REGULAR CASE: ['10', 'Minutes']
# > REGULAR CASE: ['10', 'Minutes']
# > REGULAR CASE: ['20mins']
# > REGULAR CASE: ['3', 'Minutes']
# > REGULAR CASE: ['1', 'minute']
# > REGULAR CASE: ['5', 'minutes']
# > REGULAR CASE: ['Approx.5', 'sec.']
# ---------------------------------------------------------------------------
# InvalidOperation                          Traceback (most recent call last)
# <ipython-input-25-1c275df7e380> in <module>
# ----> 1 df['Duration'].apply(lambda x: to_seconds(x, regex))
#
# e:\Projects\data-science\.venv\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-25-1c275df7e380> in <lambda>(x)
# ----> 1 df['Duration'].apply(lambda x: to_seconds(x, regex))
#
# <ipython-input-24-516c2d81ae71> in to_seconds(human_readable_duration, regex)
#      60     if not isinstance(human_readable_duration, str):
#      61         return (None, WrongTypeException(human_readable_duration))
# ---> 62     duration, time_frame, err = extract_time(human_readable_duration, regex)
#      63     if time_frame is not False:
#      64         if time_frame.lower() in TF_SECONDS:
#
# <ipython-input-24-516c2d81ae71> in extract_time(human_readable_duration, regex)
#      36     duration = -1
#      37     time_frame = False
# ---> 38     matches, clean_str = get_matches(human_readable_duration, regex)
#      39     if len(matches) == 0:
#      40         return (matches, time_frame, MatchingTimeNotFoundException(clean_str, regex))
#
# <ipython-input-24-516c2d81ae71> in get_matches(human_readable_duration, regex)
#      28     else:
#      29         print(f'> {Fore.CYAN}REGULAR CASE:{Style.RESET_ALL} {split_str}')
# ---> 30         clean_str = t2d.convert(human_readable_duration)
#      31         matches = re.findall(regex, clean_str)
#      32
#
# e:\Projects\data-science\.venv\lib\site-packages\text2digits\text2digits.py in convert(self, text)
#      49         # Apply a set of rules to the tokens to combine the numeric tokens and replace them with the corresponding digit
#      50         # e.g. I [WordType.Other] like [WordType.Other] 42 [ConcatenatedToken] apples [WordType.Other] (it merged the TENS and UNITS tokens)
# ---> 51         text = self._parse(tokens)
#      52
#      53         return text
#
# e:\Projects\data-science\.venv\lib\site-packages\text2digits\text2digits.py in _parse(self, tokens)
#     105                 if tokens[i].type != WordType.OTHER:
#     106                     # Check how many tokens this rule wants to process...
# --> 107                     n_match = rule.match(tokens[i:])
#     108                     if n_match > 0:
#     109                         # ... and then merge these tokens into a new one (e.g. a token representing the digit)
#
# e:\Projects\data-science\.venv\lib\site-packages\text2digits\rules.py in match(self, tokens)
#      82                 last_match = MatchType.DUAl_SCALE
#      83                 last_scale = second.scale()
# ---> 84             elif first.has_large_scale() and (second.type in self.valid_types or last_match == MatchType.DUAL_HUNDRED):
#      85                 # e.g. *hundred two -> consume hundred
#      86                 # e.g. twenty one *hundred -> twenty one already consumed by the first condition
#
# e:\Projects\data-science\.venv\lib\site-packages\text2digits\tokens_basic.py in has_large_scale(self)
#      97             return True
#      98         elif self.type in [WordType.LITERAL_INT, WordType.LITERAL_FLOAT]:
# ---> 99             return Decimal(self._word) >= 100 and Decimal(self._word) % 10 == 0
#     100         else:
#     101             return False
#
# InvalidOperation: [<class 'decimal.ConversionSyntax'>]
